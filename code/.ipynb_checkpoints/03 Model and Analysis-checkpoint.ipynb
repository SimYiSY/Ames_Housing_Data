# %% [markdown]
# ![banner.png](https://storage.googleapis.com/kaggle-competitions/kaggle/5407/media/housesbanner.png)
#
# # Ames Housing Saleprice (Part 3)
#
# Estates Agent are looking for the way to accurately predict saleprice of housing in Ames. By using data science to predict the prices, we will be able to come up with more competitive prices. We are also looking for features that homeowners can look into to potentially improve the property's sales value.
#
# ## Problem Statement
#
# Create a regression model where we are able to see which features affect the price of property at sales.
#
# ## Executive Summary
#
# The data set that we will be exploring is the Ames Iowa Housing Dataset till the year 2010. In the Dataset there is a total of 81 features and 2051 columns. We will explore the data to see the correlation the features have to saleprice, and also to build a regression model to predict the saleprice of housing.
#
# ### Contents:
# - [7. Model_Benchmarks](#7.-Model-Benchmarks)
# - [8. Model_Tuning](#8.-Model-Tuning)
# - [9. Kaggle Submission](#9.-Kaggle-Submission)
# - [10. Analysis & Recommendation](#10.-Analysis)
#
#
# Links:
# [Kaggle challenge link](https://www.kaggle.com/c/dsi-us-6-project-2-regression-challenge/data)

# %% [markdown]
# # 7. Model Benchmarks
# <a href='#7.-Model-Benchmarks'></a>

# %%
#Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression, Ridge, RidgeCV, Lasso, LassoCV, ElasticNet, ElasticNetCV
from sklearn.model_selection import cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import PolynomialFeatures
from sklearn.metrics import mean_squared_error, r2_score
plt.style.use('ggplot')
from IPython.display import display
pd.set_option('display.max_rows', 3000)
pd.set_option('display.max_columns', 200)
pd.set_option('display.width', 1000)

# %%
# Importing cleaned dataset for Pre Processing
df_train= pd.read_csv('../datasets/train_preprocess.csv')

df_train.shape
# Out:
# (2018, 144)

# %% [markdown]
# ## 7.1 Train Split Test

# %%
col_keys = df_train.drop(columns = ['Id','SalePrice']).keys()
col_keys
# Out:
# Index(['Year Built', 'Year Remod/Add', 'Bsmt Qual', 'Central Air', '1st Flr SF', 'Full Bath', 'Kitchen Qual', 'TotRms AbvGrd', 'Garage Finish', 'Garage Cars',
#        ...
#        'Heating_GasW', 'Heating_Grav', 'Heating_OthW', 'Heating_Wall', 'Garage Type_2Types', 'Garage Type_Attchd', 'Garage Type_Basment', 'Garage Type_BuiltIn', 'Garage Type_CarPort', 'Garage Type_Detchd'], dtype='object', length=142)

# %%
y = df_train['SalePrice']
X = df_train[col_keys]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42, test_size = 0.2)

# %%
print('X_train shape: ' + str(X_train.shape))
print('X_test shape: ' + str(X_test.shape))
print('y_train shape: ' + str(y_train.shape))
print('y_test shape: ' + str(y_test.shape))
# Out:
# X_train shape: (1614, 142)
# X_test shape: (404, 142)
# y_train shape: (1614,)
# y_test shape: (404,)

# %% [markdown]
# ## 7.1.1 Linear

# %%
lr = LinearRegression()

# %%
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print("Train Score(Lr): " + str(lr.score(X_train,y_train)))
print("Test Score(Lr): " + str(lr.score(X_test,y_test)))
print('Test Data Estimated score(Lr) ' + str(cross_val_score(lr, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(Lr): 0.8959657835940088
# Test Score(Lr): 0.8706571902467304
# Test Data Estimated score(Lr) -3.6144337970365187e+21

# %%
print("Train MSE(Lr) " + str(mean_squared_error(y_train, lr.predict(X_train))))
print('Test MSE(Lr) ' + str(mean_squared_error(y_test, lr.predict(X_test))))
                              
print('Test Data Estimated MSE(Lr) ' + str(-cross_val_score(lr, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean()))
# Out:
# Train MSE(Lr) 550113583.4423792
# Test MSE(Lr) 727496732.8019803
# Test Data Estimated MSE(Lr) 1.9494659558455204e+31

# %%
def model_evaluation_plots(model, X_train, y_train, X_test, y_test):
    y_train_preds = model.predict(X_train)
    y_test_preds = model.predict(X_test)
    
    plt.figure(figsize=(12,6))
    # Residuals
    plt.subplot(121)
    plt.scatter(y_train_preds, y_train_preds - y_train, c='tomato', marker='o', label='Training data')
    plt.scatter(y_test_preds, y_test_preds - y_test, c='gold', marker='s', label='Validation data')
    plt.title('Residuals')
    plt.xlabel('Predicted values')
    plt.ylabel('Residuals')
    plt.legend(loc='upper left')
    plt.hlines(y=0, xmin=y_train.min(), xmax=y_train.max(), color='blue')

    # Predictions
    plt.subplot(122)
    plt.scatter(y_train_preds, y_train, c='tomato', marker='o', label='Training data')
    plt.scatter(y_test_preds, y_test, c='gold', marker='s', label='Validation data')
    plt.title('Predictions')
    plt.xlabel('Predicted values')
    plt.ylabel('Real values')
    plt.legend(loc='upper left')
    plt.plot([y_train.min(), y_train.max()], [y_train.min(), y_train.max()], c='blue')
    plt.tight_layout()
    plt.show()

# %%
model_evaluation_plots(lr, X_train, y_train, X_test, y_test)

# %% [markdown]
# ### 7.1.1 comments
# - Terrible result, models is severely overfitted resulting in a negative r2 value
# - Will use Ridge, Lasso and Elastic model to regularize data

# %% [markdown]
# ## 7.1.2 Ridge

# %%
ridge = RidgeCV(alphas = np.linspace(0.1,10,100))

# %%
ridge.fit(X_train, y_train);

# %%
ridge.alpha_
# Out:
# 2.5000000000000004

# %%
print("Train Score(L1): " + str(ridge.score(X_train,y_train)))
print("Test Score(L1): " + str(ridge.score(X_test,y_test)))
print('Test Data Estimated score(L1) ' + str(cross_val_score(ridge, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(L1): 0.9003291627746131
# Test Score(L1): 0.8794654503306518
# Test Data Estimated score(L1) 0.8801424766832205

# %%
print("Train RMSE(L1) " + str(np.sqrt(mean_squared_error(y_train, ridge.predict(X_train)))))
print('Test RMSE(L1) ' + str(np.sqrt(mean_squared_error(y_test, ridge.predict(X_test)))))
                              
print('Test Data Estimated RMSE(L1) ' + str(np.sqrt(-cross_val_score(ridge, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L1) 22957.370189783273
# Test RMSE(L1) 26037.552158251474
# Test Data Estimated RMSE(L1) 25162.00333101752

# %%
model_evaluation_plots(ridge, X_train, y_train, X_test, y_test)

# %% [markdown]
# # 7.1.3 Lasso

# %%
lasso = LassoCV(alphas = np.linspace(0.1,10,100), max_iter = 4000)

# %%
lasso.fit(X_train, y_train);

# %%
lasso.alpha_
# Out:
# 10.0

# %%
print("Train Score(L2): " + str(lasso.score(X_train,y_train)))
print("Test Score(L2): " + str(lasso.score(X_test,y_test)))
print('Test Data Estimated score(L2) ' + str(cross_val_score(lasso, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(L2): 0.9024414591177746
# Test Score(L2): 0.8784750979316709
# Test Data Estimated score(L2) 0.879734831015044

# %%
print("Train RMSE(L2) " + str(np.sqrt(mean_squared_error(y_train, lasso.predict(X_train)))))
print('Test RMSE(L2) ' + str(np.sqrt(mean_squared_error(y_test, lasso.predict(X_test)))))
                              
print('Test Data Estimated RMSE(L2) ' + str(np.sqrt(-cross_val_score(lasso, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L2) 22712.802907324545
# Test RMSE(L2) 26144.299980623324
# Test Data Estimated RMSE(L2) 25207.36981791834

# %%
model_evaluation_plots(lasso, X_train, y_train, X_test, y_test)

# %% [markdown]
# # 7.1.4 Elastic Net

# %%
elasticnet = ElasticNetCV(alphas = np.linspace(0.1,10,100), max_iter = 1500)

# %%
elasticnet.fit(X_train, y_train);

# %%
elasticnet.alpha_
# Out:
# 0.1

# %%
print("Train Score(EN): " + str(elasticnet.score(X_train,y_train)))
print("Test Score(EN): " + str(elasticnet.score(X_test,y_test)))
print('Test Data Estimated score(EN) ' + str(cross_val_score(elasticnet, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(EN): 0.8800360078068928
# Test Score(EN): 0.8655160276810465
# Test Data Estimated score(EN) 0.8714783659836363

# %%
print("Train RMSE(EN) " + str(np.sqrt(mean_squared_error(y_train, elasticnet.predict(X_train)))))
print('Test RMSE(EN) ' + str(np.sqrt(mean_squared_error(y_test, elasticnet.predict(X_test)))))
                              
print('Test Data Estimated RMSE(EN) ' + str(np.sqrt(-cross_val_score(elasticnet, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(EN) 25186.25169564067
# Test RMSE(EN) 27502.972995445663
# Test Data Estimated RMSE(EN) 26048.879012710153

# %%
model_evaluation_plots(elasticnet, X_train, y_train, X_test, y_test)

# %% [markdown]
# # 7 comments
#
# - the prediction is better after regularising
# - all 3 models are producing very similar RMSE and R2 scores
# - there seems to be a spread of residuals in all 3 models
# - the data seem to move away from best fit line at higher prices

# %% [markdown]
# # 8 Model Tuning
# <a href='#8.-Model-Tuning'></a>`

# %% [markdown]
# - Will look at the top 50 coefficient to see how they affect SalePrice

# %%
coef = pd.Series(lasso.coef_, index = X_train.columns)
coef.sort_values(ascending = False, inplace = True)
coef[abs(coef) > 0][:50] #top 50 coefficient features, regardless of positive or negative
# Out:
# Neighborhood_GrnHill     112361.686036
# Neighborhood_NridgHt      46911.277033
# Neighborhood_StoneBr      44347.590031
# Neighborhood_NoRidge      43591.713280
# Neighborhood_BrDale       43324.766250
# Condition 2_PosN          42233.552997
# Condition 2_PosA          34286.080062
# Exterior 1st_BrkFace      22251.215036
# Bldg Type_1Fam            20973.944218
# Condition 1_PosN          19748.811249
# Bldg Type_2fmCon          17508.522718
# Neighborhood_Veenker      17321.432037
# Neighborhood_ClearCr      16789.181736
# Neighborhood_Somerst      16416.264288
# Land Contour_HLS          16396.884655
# Condition 1_PosA          16216.992846
# Neighborhood_NPkVill      15450.576227
# MS Zoning_RH              15110.494337
# Total Flr SF              14869.258341
# Exterior 2nd_AsphShn      14461.796527
# Neighborhood_MeadowV      14375.242432
# House Style_2.5Unf        13819.889708
# Land Contour_Low          12455.659609
# 1st Flr SF                11776.697346
# Neighborhood_Greens       11346.123904
# Overall Total Value       11238.412255
# Bsmt Qual                 10127.033818
# Exterior 2nd_CmentBd       9457.668977
# Neighborhood_Crawfor       9360.755341
# Total Bath                 9199.496520
# Neighborhood_Timber        9089.235093
# Year Built                 8031.129263
# Roof Style_Hip             8026.593566
# Kitchen Qual               7329.852338
# Neighborhood_BrkSide       7146.677330
# Garage Total Value         6896.195433
# Garage Cars                6756.014759
# Exterior 2nd_VinylSd       6539.542498
# Condition 1_Norm           6284.187058
# Fireplace Total Value      6021.398107
# Exterior 2nd_MetalSd       5863.818658
# Neighborhood_IDOTRR        5517.285634
# Heating_GasA               4747.452694
# Neighborhood_Blmngtn       4691.965846
# Neighborhood_Sawyer        4117.746850
# Exterior 2nd_Brk Cmn       3987.027996
# Neighborhood_Mitchel       3665.058300
# Roof Style_Gable           3503.581488
# MS Zoning_FV               3296.234297
# Exterior 1st_AsbShng       3251.729966
# dtype: float64

# %% [markdown]
# - interestingly, the top 50 features all seems to be positively contributing to the SalePrice

# %%
# using top 50 without absolute function as it does not matter at this point
gd_coef = coef[:50].keys()

#keeping values with high coefficient
len(gd_coef)
# Out:
# 50

# %%
X_train_filtered = X_train[gd_coef]
X_test_filtered = X_test[gd_coef]

# %% [markdown]
# # 8.1 Linear

# %%
lr = LinearRegression()
lr.fit(X_train_filtered, y_train)
# Out:
# LinearRegression()

# %%
print("Train Score(Lr): " + str(lr.score(X_train_filtered,y_train)))
print("Test Score(Lr): " + str(lr.score(X_test_filtered,y_test)))
print('Test Data Estimated score(Lr) ' + str(cross_val_score(lr, X_train_filtered, y_train, cv = 5).mean()))
# Out:
# Train Score(Lr): 0.8926431201435228
# Test Score(Lr): 0.8705746836601942
# Test Data Estimated score(Lr) 0.8788149018286529

# %%
print("Train RMSE(Lr) " + str(np.sqrt(mean_squared_error(y_train, lr.predict(X_train_filtered)))))
print('Test RMSE(Lr) ' + str(np.sqrt(mean_squared_error(y_test, lr.predict(X_test_filtered)))))
                              
print('Test Data Estimated RMSE(Lr) ' + str(np.sqrt(-cross_val_score(lr, X_train_filtered, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(Lr) 23826.103535235492
# Test RMSE(Lr) 26980.748623128504
# Test Data Estimated RMSE(Lr) 25299.309663745542

# %%
model_evaluation_plots(lr, X_train_filtered, y_train, X_test_filtered, y_test)

# %% [markdown]
# ##  8.1 Comments
#
# - Tried with 25, 30, 40, 50, 55 features for test, 50 features returns the best results
# - using only the top 50 features seems to improve the RMSE and R2 scores
# - Trying with Lasso model

# %% [markdown]
# # 8.2 Lasso

# %%
lasso = LassoCV(alphas = np.linspace(0.1,10,100), max_iter = 1500)

# %%
lasso.fit(X_train_filtered, y_train);

# %%
lasso.alpha_
# Out:
# 10.0

# %%
print("Train Score(L2): " + str(lasso.score(X_train_filtered,y_train)))
print("Test Score(L2): " + str(lasso.score(X_test_filtered,y_test)))
print('Test Data Estimated score(L2) ' + str(cross_val_score(lasso, X_train_filtered, y_train, cv = 5).mean()))
# Out:
# Train Score(L2): 0.892476279782878
# Test Score(L2): 0.871264608643974
# Test Data Estimated score(L2) 0.8791510061711003

# %%
print("Train RMSE(L2) " + str(np.sqrt(mean_squared_error(y_train, lasso.predict(X_train_filtered)))))
print('Test RMSE(L2) ' + str(np.sqrt(mean_squared_error(y_test, lasso.predict(X_test_filtered)))))
                              
print('Test Data Estimated RMSE(L2) ' + str(np.sqrt(-cross_val_score(lasso, X_train_filtered, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L2) 23844.61009248121
# Test RMSE(L2) 26908.73965815981
# Test Data Estimated RMSE(L2) 25262.187079468822

# %%
model_evaluation_plots(lasso, X_train_filtered, y_train, X_test_filtered, y_test)

# %% [markdown]
# - Not surprisingly, the RMSE and R2 scores are very similar to Linear model
# - the prediction are still not that good at higher pricest

# %% [markdown]
# # 8.3 Further Model tuning
#
# - Polynomial features, to see if we can increase accuracy of the model

# %% [markdown]
# # 8.3.1 Heatmap for features

# %%
coef_sort = [i for i in gd_coef.sort_values()]
plt.figure(figsize= (20, 15))
mask = (np.triu(np.ones_like(df_train[coef_sort].corr(),
                             dtype=np.bool)))
sns.heatmap(df_train[coef_sort].corr(),
            annot=False, mask = mask, 
            fmt='.1g', cmap='coolwarm');

# %% [markdown]
# Very few patches of data with Correlation to each other

# %% [markdown]
# ##  8.3.3 Adding in relevant Polynomial features to training and testing dataset

# %% [markdown]
# - will be choosing features where the correlation to saleprice increase alot more at higher prices
# - '1st Flr SF', 'Garage Cars','Year Built', 'Overall Total Value', 'Garage Total Value', 'Total Bath', 'Total Flr SF', 'Kitchen Qual', 'Fireplace Total Value' are chosen as they are the only continuous data left after regularisation

# %% [markdown]
# ### 8.3.3 Creating Polynomial Features

# %%
#def function to scatter plot data agaisnt sale price
def subplot_scatter(x, dataframe = df_train):
    nrows = int(np.ceil(len(x)/3)) # Makes sure you have enough rows
    fig, ax = plt.subplots(nrows=nrows, ncols=3, figsize=(15, 4*nrows)) # You'll want to specify your figsize
    plt.subplots_adjust(hspace = 0.4, wspace = 0.4)
    ax = ax.ravel() # Ravel turns a matrix into a vector, which is easier to iterate
    for i, column in enumerate(x):  # Gives us an index value to get into all our lists
        sns.regplot(x = dataframe[column], 
                    y = dataframe['SalePrice'],
                    data = dataframe, 
                    ax = ax[i], line_kws = {'color':'b'})#plot Scatter plot for each data
        ax[i].set_xlabel(x[i])# Set x label for each plot

# %%
poly_coef = ['1st Flr SF', 'Garage Cars','Year Built', 'Overall Total Value', 'Garage Total Value',
             'Total Bath', 'Total Flr SF', 'Kitchen Qual', 'Fireplace Total Value']
subplot_scatter(poly_coef)

# %%
y = df_train['SalePrice']
X = df_train[poly_coef]

# %%
print("Garage & Total & Year Features Train Score(L2): " + str(cross_val_score(lasso, X = X, y = y, cv = 5).mean()))
# Out:
# Garage & Total & Year Features Train Score(L2): 0.8237053823208671

# %%
poly = PolynomialFeatures(degree = 2, interaction_only = True, include_bias=False)

# %%
X_poly = poly.fit_transform(X)

# %%
print("Polynomial Garage & Total & Year Features Train Score(L2): " + str(cross_val_score(lasso, X_poly, y, cv=5).mean()))
# Out:
# Polynomial Garage & Total & Year Features Train Score(L2): 0.8939097953245062

# %% [markdown]
# - R2 score improved after using polynomial features

# %% [markdown]
# ## 8.3.4 adding Polynomial Features into training dataset

# %%
poly_features = pd.DataFrame(X_poly, columns=poly.get_feature_names(poly_coef))
poly_features.drop(poly_coef, axis = 1, inplace = True)
poly_features.shape
# Out:
# (2018, 36)

# %%
poly_features.columns
# Out:
# Index(['1st Flr SF Garage Cars', '1st Flr SF Year Built', '1st Flr SF Overall Total Value', '1st Flr SF Garage Total Value', '1st Flr SF Total Bath', '1st Flr SF Total Flr SF', '1st Flr SF Kitchen Qual', '1st Flr SF Fireplace Total Value', 'Garage Cars Year Built', 'Garage Cars Overall Total Value', 'Garage Cars Garage Total Value', 'Garage Cars Total Bath', 'Garage Cars Total Flr SF', 'Garage Cars Kitchen Qual', 'Garage Cars Fireplace Total Value', 'Year Built Overall Total Value', 'Year Built Garage Total Value', 'Year Built Total Bath', 'Year Built Total Flr SF', 'Year Built Kitchen Qual', 'Year Built Fireplace Total Value', 'Overall Total Value Garage Total Value', 'Overall Total Value Total Bath', 'Overall Total Value Total Flr SF', 'Overall Total Value Kitchen Qual', 'Overall Total Value Fireplace Total Value', 'Garage Total Value Total Bath', 'Garage Total Value Total Flr SF', 'Garage Total Value Kitchen Qual', 'Garage Total Value Fireplace Total Value',
#        'Total Bath Total Flr SF', 'Total Bath Kitchen Qual', 'Total Bath Fireplace Total Value', 'Total Flr SF Kitchen Qual', 'Total Flr SF Fireplace Total Value', 'Kitchen Qual Fireplace Total Value'],
#       dtype='object')

# %%
df_train_poly = pd.concat([df_train, poly_features], axis = 1)
df_train_poly.shape
# Out:
# (2018, 180)

# %% [markdown]
# # 8.4 Lasso Model with Polynomial Features

# %%
col_keys = df_train_poly.drop(columns = ['Id','SalePrice']).keys()
col_keys
# Out:
# Index(['Year Built', 'Year Remod/Add', 'Bsmt Qual', 'Central Air', '1st Flr SF', 'Full Bath', 'Kitchen Qual', 'TotRms AbvGrd', 'Garage Finish', 'Garage Cars',
#        ...
#        'Garage Total Value Total Bath', 'Garage Total Value Total Flr SF', 'Garage Total Value Kitchen Qual', 'Garage Total Value Fireplace Total Value', 'Total Bath Total Flr SF', 'Total Bath Kitchen Qual', 'Total Bath Fireplace Total Value', 'Total Flr SF Kitchen Qual', 'Total Flr SF Fireplace Total Value', 'Kitchen Qual Fireplace Total Value'], dtype='object', length=178)

# %%
y = df_train_poly['SalePrice']
X = df_train_poly[col_keys]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42, test_size = 0.2)

# %%
print('X_train shape: ' + str(X_train.shape))
print('X_test shape: ' + str(X_test.shape))
print('y_train shape: ' + str(y_train.shape))
print('y_test shape: ' + str(y_test.shape))
# Out:
# X_train shape: (1614, 178)
# X_test shape: (404, 178)
# y_train shape: (1614,)
# y_test shape: (404,)

# %%
lasso = LassoCV(alphas = np.linspace(0.1,10,100), max_iter = 5000)
lasso.fit(X_train, y_train);
lasso.alpha_
# Out:
# 10.0

# %%
print("Train Score(L2): " + str(lasso.score(X_train,y_train)))
print("Test Score(L2): " + str(lasso.score(X_test,y_test)))
print('Test Data Estimated score(L2) ' + str(cross_val_score(lasso, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(L2): 0.9324374091002131
# Test Score(L2): 0.9170995833903596
# Test Data Estimated score(L2) 0.9101736327645943

# %%
print("Train RMSE(L2) " + str(np.sqrt(mean_squared_error(y_train, lasso.predict(X_train)))))
print('Test RMSE(L2) ' + str(np.sqrt(mean_squared_error(y_test, lasso.predict(X_test)))))
                              
print('Test Data Estimated RMSE(L2) ' + str(np.sqrt(-cross_val_score(lasso, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L2) 18901.28070743525
# Test RMSE(L2) 21593.484766929472
# Test Data Estimated RMSE(L2) 21783.16776393895

# %%
model_evaluation_plots(lasso, X_train, y_train, X_test, y_test)

# %% [markdown]
# ### 8.3 comments :
# - Results improved after inserting polynomial features
# - RMSE scores are lower, and R2 scores are slighlty higher
# - Residual plot also see less spread of the data

# %% [markdown]
# # 8.4  Lasso and Ridge Model after removing low coef columns
#
# - filtering out top coefficients features

# %%
coef = pd.Series(lasso.coef_, index = X_train.columns)
coef.sort_values(ascending = False, inplace = True) # sort value by importance of value

# %%
coef_sort = [i for i in coef[coef != 0].keys().sort_values()] # creating list of coef not equal to zero
len(coef_sort)
# Out:
# 147

# %% [markdown]
# - Choosing features that is contributing to saleprice after regularisation

# %% [markdown]
# ## 8.4.1 Lasso model

# %%
y = df_train_poly['SalePrice']
X = df_train_poly[coef_sort]

# %%
X_train, X_test, y_train, y_test = train_test_split(X,y,random_state = 42, test_size = 0.2)

# %%
print('X_train shape: ' + str(X_train.shape))
print('X_test shape: ' + str(X_test.shape))
print('y_train shape: ' + str(y_train.shape))
print('y_test shape: ' + str(y_test.shape))
# Out:
# X_train shape: (1614, 147)
# X_test shape: (404, 147)
# y_train shape: (1614,)
# y_test shape: (404,)

# %%
re_lasso = LassoCV(alphas = np.linspace(0.1,10,100), max_iter = 3000)
re_lasso.fit(X_train, y_train);
re_lasso.alpha_
# Out:
# 10.0

# %%
print("Train Score(L2): " + str(re_lasso.score(X_train,y_train)))
print("Test Score(L2): " + str(re_lasso.score(X_test,y_test)))
print('Test Data Estimated score(L2) ' + str(cross_val_score(re_lasso, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(L2): 0.9324369828840506
# Test Score(L2): 0.9171035452234261
# Test Data Estimated score(L2) 0.911817268274141

# %%
print("Train RMSE(L2) " + str(np.sqrt(mean_squared_error(y_train, re_lasso.predict(X_train)))))
print('Test RMSE(L2) ' + str(np.sqrt(mean_squared_error(y_test, re_lasso.predict(X_test)))))
                              
print('Test Data Estimated RMSE(L2) ' + str(np.sqrt(-cross_val_score(re_lasso, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L2) 18901.34032636427
# Test RMSE(L2) 21592.968781560485
# Test Data Estimated RMSE(L2) 21579.15050680669

# %%
model_evaluation_plots(re_lasso, X_train, y_train, X_test, y_test)

# %% [markdown]
# ## 8.4.2 Ridge Model

# %%
re_ridge = RidgeCV(alphas = np.linspace(0.1,10,100))

# %%
re_ridge.fit(X_train, y_train);

# %%
re_ridge.alpha_
# Out:
# 0.6

# %%
print("Train Score(L1): " + str(re_ridge.score(X_train,y_train)))
print("Test Score(L1): " + str(re_ridge.score(X_test,y_test)))
print('Test Data Estimated score(L1) ' + str(cross_val_score(re_ridge, X_train, y_train, cv = 5).mean()))
# Out:
# Train Score(L1): 0.93254072713841
# Test Score(L1): 0.9168396973421808
# Test Data Estimated score(L1) 0.9103171058064436

# %%
print("Train RMSE(L1) " + str(np.sqrt(mean_squared_error(y_train, re_ridge.predict(X_train)))))
print('Test RMSE(L1) ' + str(np.sqrt(mean_squared_error(y_test, re_ridge.predict(X_test)))))
                              
print('Test Data Estimated RMSE(L1) ' + str(np.sqrt(-cross_val_score(re_ridge, X_train, y_train, 
                                                            cv = 5, scoring = 'neg_mean_squared_error').mean())))
# Out:
# Train RMSE(L1) 18886.823073639593
# Test RMSE(L1) 21627.30518884532
# Test Data Estimated RMSE(L1) 21762.68510492752

# %%
model_evaluation_plots(re_ridge, X_train, y_train, X_test, y_test)

# %% [markdown]
# # 8.4 Comments
# - Decrease in RMSE, the gap between the R2 scores are smaller
# - it can be inferred that the accuracy to unknown data is improved
# - will use the top 50 coefficient features for the final model

# %% [markdown]
# # 9 Kaggle Submission
# <a href='#9.-Kaggle-Submission'></a>
# - will submit final prediction of lasso and ridge models to Kaggle

# %% [markdown]
# # 9.1 Preparing Test Data

# %%
# importing data for unknown test data prediction
df_test= pd.read_csv('../datasets/test_preprocess.csv')

df_test.shape
# Out:
# (879, 137)

# %%
# in test - train
df_test_col = df_test.columns.difference(df_train.columns)

# in train not in test
df_train_col =  df_train.columns.difference(df_test.columns)

# dropping values not in training set
df_test.drop(columns = df_test_col, inplace = True)

# adding values in training set not in testing set
for i in df_train_col:
    df_test[i] = 0
    
#filling in possible null values    
df_test.fillna(0 ,inplace = True)

#Creating Polynomial Features for unknown data
X_df_test = df_test[poly_coef]
X_test_poly = poly.fit_transform(X_df_test)

#Creating Polynomial Dataframe to add into test data
poly_test_features = pd.DataFrame(X_test_poly, columns=poly.get_feature_names(poly_coef))
poly_test_features.drop(poly_coef, axis = 1, inplace = True)

#adding features together for prediction models
df_test_poly = pd.concat([df_test, poly_test_features], axis = 1)

# %% [markdown]
# # 9.2 Predicting Saleprice of unknown test data

# %%
X_df_test = df_test_poly[coef_sort]

# %%
lasso_test_predict = re_lasso.predict(X_df_test)
ridge_test_predict = re_ridge.predict(X_df_test)

# %%
print(len(lasso_test_predict))
print(len(ridge_test_predict))
# Out:
# 879
# 879

# %%
df_lasso_predicted = pd.DataFrame(lasso_test_predict, columns = ['SalePrice'])
df_ridge_predicted = pd.DataFrame(ridge_test_predict, columns = ['SalePrice'])

# %%
print(df_lasso_predicted.head())
print(df_ridge_predicted.head())
# Out:
#        SalePrice
# 0  125508.905547
# 1  159941.493849
# 2  183869.512770
# 3  109060.628143
# 4  178542.509250
#        SalePrice
# 0  125120.257512
# 1  159957.417152
# 2  183696.587676
# 3  109142.806749
# 4  177690.301796

# %%
submit_lasso = pd.concat([df_test['Id'], df_lasso_predicted['SalePrice']], 
                   ignore_index=False, sort=False, axis = 1)

submit_ridge = pd.concat([df_test['Id'], df_ridge_predicted['SalePrice']], 
                   ignore_index=False, sort=False, axis = 1)

# %%
submit_lasso.sort_values('Id', ascending = True, inplace = True)
submit_lasso.head()
# Out:
#      Id      SalePrice
# 704   2  121470.997364
# 706   4  287837.810135
# 120   6  190100.247957
# 312   7  232185.066792
# 401  17  196673.288878

# %%
submit_ridge.sort_values('Id', ascending = True, inplace = True)
submit_ridge.head()
# Out:
#      Id      SalePrice
# 704   2  123072.135226
# 706   4  286405.853681
# 120   6  190454.210215
# 312   7  231805.117023
# 401  17  196247.542221

# %%
submit_lasso.to_csv("../datasets/submission_lasso.csv", index=False)
submit_ridge.to_csv("../datasets/submission_ridge.csv", index=False)

# %% [markdown]
# # Submission result
#
# ![submission.PNG](attachment:submission.PNG)

# %% [markdown]
# # 10. Analysis
# <a href='#10.-Analysis'></a>

# %% [markdown]
# - Plotting out charts to see which features has an impact on SalePrice
# - List down a few features homeowners should look out for

# %%
coef_50 = coef[abs(coef).sort_values(ascending = False)[:50].keys()].sort_values(ascending = False)

# %%
df_coef_50 = pd.DataFrame(coef_50).reset_index().rename(columns = {'index': 'Features', 0: 'Coefficient'})
df_coef_50.head(10)
# Out:
#                Features    Coefficient
# 0  Neighborhood_GrnHill  110918.880759
# 1  Neighborhood_StoneBr   33923.168379
# 2  Neighborhood_NridgHt   24246.369568
# 3  Neighborhood_NoRidge   21774.209975
# 4          Total Flr SF   21441.342667
# 5  Exterior 1st_BrkFace   21148.610996
# 6  Neighborhood_ClearCr   20602.507530
# 7      Condition 2_PosA   20044.143296
# 8  Exterior 2nd_AsphShn   17534.049150
# 9      Condition 2_PosN   15959.871845

# %%
df_coef_50.groupby('Features')['Coefficient'].sum()
# Out:
# Features
# 1st Flr SF               10920.798950
# Bldg Type_1Fam           13260.091204
# Bldg Type_2fmCon         13643.523999
# Bldg Type_Twnhs         -13254.460771
# Bldg Type_TwnhsE         -5142.379293
# Bsmt Qual                 5706.028744
# Condition 1_Norm          4929.277590
# Condition 1_PosA         12603.278411
# Condition 1_PosN          9366.721298
# Condition 1_RRAe         -5441.051856
# Condition 1_RRNn        -15787.296427
# Condition 2_PosA         20044.143296
# Condition 2_PosN         15959.871845
# Exterior 1st_BrkFace     21148.610996
# Exterior 1st_Stone       -8537.230344
# Exterior 1st_WdShing      6827.373553
# Exterior 2nd_AsphShn     17534.049150
# Exterior 2nd_ImStucc    -10754.959992
# Garage Total Value        8978.419884
# Heating_Grav            -22943.117239
# Heating_OthW            -16015.593776
# House Style_2.5Unf       10539.687295
# House Style_SFoyer        8055.175224
# Land Contour_HLS          9814.006175
# Land Contour_Low         11795.384455
# MS Zoning_C (all)       -17038.021454
# MS Zoning_FV              6510.631991
# MS Zoning_RH              9718.510055
# Mas Vnr Type_BrkCmn      -7566.720276
# Neighborhood_Blmngtn     -5414.538362
# Neighborhood_BrDale      15485.494750
# Neighborhood_ClearCr     20602.507530
# Neighborhood_Crawfor      8532.014451
# Neighborhood_Edwards     -5465.156003
# Neighborhood_Greens       9173.436342
# Neighborhood_GrnHill    110918.880759
# Neighborhood_NPkVill     10712.515289
# Neighborhood_NWAmes      -6527.610180
# Neighborhood_NoRidge     21774.209975
# Neighborhood_NridgHt     24246.369568
# Neighborhood_Somerst     10328.427778
# Neighborhood_StoneBr     33923.168379
# Neighborhood_Timber       8006.836024
# Overall Total Value      12526.039188
# Roof Style_Gambrel       -7962.954501
# Roof Style_Hip            4861.584259
# Roof Style_Mansard      -41051.215649
# Total Bath                7641.129985
# Total Flr SF             21441.342667
# Year Built               10987.816390
# Name: Coefficient, dtype: float64

# %%
plt.figure(figsize= (20, 15))
sns.barplot(x = df_coef_50['Coefficient'], y = df_coef_50['Features']);

# %% [markdown]
# ## 10 comments
# - From a glance, it looks like the location where the house is built matters the most for saleprice
#   - Neighborhood seems to affect salesprice the most
#   - Condition of the house (Proximity to main road or railroad), where it is near to main and railroad on both conditions seems to improve saleprice
#
#
# - will attempt to remove features that homeowners are unable to make changes to their house (e.g Neighborhood, Condition, Land Contour)

# %%
df_recommend = df_coef_50[~df_coef_50['Features'].str
                          .contains('Neigh|Cond|Land')].sort_values(by = 'Coefficient', 
                                                                    ascending = False)
print((str(len(df_recommend['Features'])) + ' features recommended'))
df_recommend
# Out:
# 27 features recommended
#                 Features   Coefficient
# 4           Total Flr SF  21441.342667
# 5   Exterior 1st_BrkFace  21148.610996
# 8   Exterior 2nd_AsphShn  17534.049150
# 11      Bldg Type_2fmCon  13643.523999
# 12        Bldg Type_1Fam  13260.091204
# 14   Overall Total Value  12526.039188
# 16            Year Built  10987.816390
# 17            1st Flr SF  10920.798950
# 19    House Style_2.5Unf  10539.687295
# 22          MS Zoning_RH   9718.510055
# 25    Garage Total Value   8978.419884
# 27    House Style_SFoyer   8055.175224
# 29            Total Bath   7641.129985
# 30  Exterior 1st_WdShing   6827.373553
# 31          MS Zoning_FV   6510.631991
# 32             Bsmt Qual   5706.028744
# 34        Roof Style_Hip   4861.584259
# 35      Bldg Type_TwnhsE  -5142.379293
# 40   Mas Vnr Type_BrkCmn  -7566.720276
# 41    Roof Style_Gambrel  -7962.954501
# 42    Exterior 1st_Stone  -8537.230344
# 43  Exterior 2nd_ImStucc -10754.959992
# 44       Bldg Type_Twnhs -13254.460771
# 46          Heating_OthW -16015.593776
# 47     MS Zoning_C (all) -17038.021454
# 48          Heating_Grav -22943.117239
# 49    Roof Style_Mansard -41051.215649

# %%
#function to plot barplot within categories
def barh_plot(label, df = df_recommend):
    dataframe = df[df['Features'].str.contains(label)].sort_values(by = 'Coefficient', ascending = False)
    plt.figure(figsize= (10, 6))
    plt.title(str(label) + ' Features Coefficient')
    sns.barplot(x = dataframe['Coefficient'], y = dataframe['Features']);

# %%
barh_plot('Exterior')

# %% [markdown]
# Comments:
#
# - Houses with BrickFace and Asphalt Shingles Exterior tend increase the SalePrice of property

# %%
barh_plot('Bldg')

# %% [markdown]
# Comments:
#
# Features that has a higher coefficient to SalePrice
# - 1Fam Single-family Detached
# - 2FmCon Two-family Conversion; originally built as one-family dwelling

# %%
barh_plot('Heating')

# %% [markdown]
# Comments:
#
# - Wall Furnance worth more as compared to other heating features
# - good to note that having a heating of the below categories lowers the value of property significantly
#   - OthW Hot water or steam heat other than gas
#   - Grav Gravity furnace

# %%
barh_plot('Year|Bsmt|Roof')

# %% [markdown]
# Comments:
#
# - The newer the property, the higher the SalePrice
# - Having a good Basement quality improves sale price
# - Avoiding Mansard roof for the property as it negatively impact SalePrice significantly

# %%
barh_plot('Total')

# %% [markdown]
# Comments:
#
# - Improving the overall quality the houses will increase value of property
# - Total Flr SF, the bigger the space, the better
# - Quality of house will improve the SalePrice as it gets better
# - The Total Value of the Garage has an positive impact on Saleprice
# - Fireplace Total Value, more fireplace with better quality increase value of property
# - Total Bath, the more bath, the better

# %%
barh_plot('House')

# %% [markdown]
# Comments:
#
# Features that improve value:
# - SFoyer Split Foyer
# - 2.5Unf Two and one-half story: 2nd level unfinished
#
# Features that reduce value:
# - 2.5Fin Two and one-half story: 2nd level finished
# - 2Story Two story
#
# Interesting to note that, having a unfinished 2nd level of a 2.5 story building actually fetches a better price then a finished one. There might be some other factors that has to be put into consideration

# %% [markdown]
# # 10.1 Recommendations:

# %% [markdown]
# Below are a list of what homeowners can do to improve their property SalePrice

# %% [markdown]
# - Ames House buyers generally values luxury, quality and space of the houses
#
#
# - Certain features enhancement will improve saleprice:
#   - Heating, Fireplace, Garage, Baths
#
#
# - Having a good exterior of the house will fetch a higher price
#
#
# - The newer the house, the better the price
