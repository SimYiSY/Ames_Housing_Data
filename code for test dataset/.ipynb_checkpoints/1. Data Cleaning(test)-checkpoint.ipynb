# %% [markdown]
# # Ames Housing Saleprice
#
# ## Problem Statement
#
# Create a regression model where we are able to predict the price of the house at sales.

# %% [markdown]
# ## Executive Summary
#
# ### Contents:
# - [1. Importing of libraries](#1.-Importing-of-Libraries)
# - [2. Importing Dataset](#2.-Importing-of-Dataset)
# - [3. Manual Check of Dataset](#3.-Manual-Check-of-Dataset)
# - [4. Data Cleaning](#4.-Data-Cleaning)
#
#
# Links:
# [Kaggle challenge link](https://www.kaggle.com/c/dsi-us-6-project-2-regression-challenge/data)

# %% [markdown]
# # 1. Importing of Libraries

# %%
#Imports:
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import scipy.stats as stats
plt.style.use('ggplot')

# %% [markdown]
# # 2. Importing of Dataset

# %%
# Importing Data set
df_train = pd.read_csv('../datasets/test.csv')

# %%
#check data set imported
df_train.head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour  ... 3Ssn Porch Screen Porch Pool Area Pool QC  \
# 0  Grvl       Reg          Lvl  ...          0            0         0     NaN
# 1   NaN       IR1          Lvl  ...          0            0         0     NaN
# 2   NaN       IR1          Lvl  ...          0            0         0     NaN
# 3   NaN       Reg          Lvl  ...          0            0         0     NaN
# 4   NaN       IR1          Lvl  ...          0          185         0     NaN
#
#   Fence Misc Feature Misc Val Mo Sold  Yr Sold  Sale Type
# 0   NaN          NaN        0       4     2006        WD
# 1   NaN          NaN        0       8     2006        WD
# 2   NaN          NaN        0       9     2006        New
# 3   NaN          NaN        0       7     2007        WD
# 4   NaN          NaN        0       7     2009        WD
#
# [5 rows x 80 columns]

# %% [markdown]
# # 3. Manual Check of Dataset

# %% [markdown]
# ## 3.1. first 20 columns

# %%
#checking shape of dataset
df_train.shape
# Out:
# (879, 80)

# %%
#As data has 81 columns, its better to split them up and check part by part.
df_train.iloc[:,:20].head()
# Out:
#      Id        PID  MS SubClass MS Zoning  Lot Frontage  Lot Area Street  \
# 0  2658  902301120          190        RM          69.0      9142   Pave
# 1  2718  905108090           90        RL           NaN      9662   Pave
# 2  2414  528218130           60        RL          58.0     17104   Pave
# 3  1989  902207150           30        RM          60.0      8520   Pave
# 4   625  535105100           20        RL           NaN      9500   Pave
#
#   Alley Lot Shape Land Contour Utilities Lot Config Land Slope Neighborhood  \
# 0  Grvl       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 1   NaN       IR1          Lvl    AllPub     Inside        Gtl       Sawyer
# 2   NaN       IR1          Lvl    AllPub     Inside        Gtl      Gilbert
# 3   NaN       Reg          Lvl    AllPub     Inside        Gtl      OldTown
# 4   NaN       IR1          Lvl    AllPub     Inside        Gtl        NAmes
#
#   Condition 1 Condition 2 Bldg Type House Style  Overall Qual  Overall Cond
# 0        Norm        Norm    2fmCon      2Story             6             8
# 1        Norm        Norm    Duplex      1Story             5             4
# 2        Norm        Norm      1Fam      2Story             7             5
# 3        Norm        Norm      1Fam      1Story             5             6
# 4        Norm        Norm      1Fam      1Story             6             5

# %%
#checking for data types and null objects.
df_train.iloc[:,:20].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 20 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Id            879 non-null    int64
#  1   PID           879 non-null    int64
#  2   MS SubClass   879 non-null    int64
#  3   MS Zoning     879 non-null    object
#  4   Lot Frontage  719 non-null    float64
#  5   Lot Area      879 non-null    int64
#  6   Street        879 non-null    object
#  7   Alley         58 non-null     object
#  8   Lot Shape     879 non-null    object
#  9   Land Contour  879 non-null    object
#  10  Utilities     879 non-null    object
#  11  Lot Config    879 non-null    object
#  12  Land Slope    879 non-null    object
#  13  Neighborhood  879 non-null    object
#  14  Condition 1   879 non-null    object
#  15  Condition 2   879 non-null    object
#  16  Bldg Type     879 non-null    object
#  17  House Style   879 non-null    object
#  18  Overall Qual  879 non-null    int64
#  19  Overall Cond  879 non-null    int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 137.5+ KB

# %%
df_train.iloc[:,:20].describe(include='all').T
# Out:
#              count unique     top freq         mean          std          min  \
# Id             879    NaN     NaN  NaN      1445.59      850.717            2
# PID            879    NaN     NaN  NaN  7.16505e+08  1.88914e+08  5.26302e+08
# MS SubClass    879    NaN     NaN  NaN      58.2708      42.2114           20
# MS Zoning      879      6      RL  675          NaN          NaN          NaN
# Lot Frontage   719    NaN     NaN  NaN        69.63      23.6254           21
# Lot Area       879    NaN     NaN  NaN      10340.9      10047.3         1477
# Street         879      2    Pave  874          NaN          NaN          NaN
# Alley           58      2    Grvl   35          NaN          NaN          NaN
# Lot Shape      879      4     Reg  564          NaN          NaN          NaN
# Land Contour   879      4     Lvl  790          NaN          NaN          NaN
# Utilities      879      2  AllPub  878          NaN          NaN          NaN
# Lot Config     879      5  Inside  637          NaN          NaN          NaN
# Land Slope     879      3     Gtl  836          NaN          NaN          NaN
# Neighborhood   879     26   NAmes  133          NaN          NaN          NaN
# Condition 1    879      9    Norm  755          NaN          NaN          NaN
# Condition 2    879      4    Norm  875          NaN          NaN          NaN
# Bldg Type      879      5    1Fam  725          NaN          NaN          NaN
# House Style    879      8  1Story  422          NaN          NaN          NaN
# Overall Qual   879    NaN     NaN  NaN      6.05461      1.37476            2
# Overall Cond   879    NaN     NaN  NaN      5.56542      1.12842            1
#
#                       25%          50%          75%         max
# Id                  692.5         1435         2197        2928
# PID           5.28486e+08  5.35454e+08  9.07192e+08  1.0071e+09
# MS SubClass            20           50           70         190
# MS Zoning             NaN          NaN          NaN         NaN
# Lot Frontage           59           68           80         182
# Lot Area           7298.5         9453      11606.5      215245
# Street                NaN          NaN          NaN         NaN
# Alley                 NaN          NaN          NaN         NaN
# Lot Shape             NaN          NaN          NaN         NaN
# Land Contour          NaN          NaN          NaN         NaN
# Utilities             NaN          NaN          NaN         NaN
# Lot Config            NaN          NaN          NaN         NaN
# Land Slope            NaN          NaN          NaN         NaN
# Neighborhood          NaN          NaN          NaN         NaN
# Condition 1           NaN          NaN          NaN         NaN
# Condition 2           NaN          NaN          NaN         NaN
# Bldg Type             NaN          NaN          NaN         NaN
# House Style           NaN          NaN          NaN         NaN
# Overall Qual            5            6            7          10
# Overall Cond            5            5            6           9

# %% [markdown]
# ### 3.1. comments:
# - All dtypes of the 20 features are correct for what they suppose to represent
# - "PID" seems to be an unknown data to explained on the Data Dictionary.
# - Missing datas:
#   - Lot Frontage, float
#   - Alley, object
# - No Negative values noted

# %% [markdown]
# ## 3.2. Second 20 columns

# %%
#Checking 2nd 20 columns of data
df_train.iloc[:, 20:40].head()
# Out:
#    Year Built  Year Remod/Add Roof Style Roof Matl Exterior 1st Exterior 2nd  \
# 0        1910            1950      Gable   CompShg      AsbShng      AsbShng
# 1        1977            1977      Gable   CompShg      Plywood      Plywood
# 2        2006            2006      Gable   CompShg      VinylSd      VinylSd
# 3        1923            2006      Gable   CompShg      Wd Sdng      Wd Sdng
# 4        1963            1963      Gable   CompShg      Plywood      Plywood
#
#   Mas Vnr Type  Mas Vnr Area Exter Qual Exter Cond Foundation Bsmt Qual  \
# 0         None           0.0         TA         Fa      Stone        Fa
# 1         None           0.0         TA         TA     CBlock        Gd
# 2         None           0.0         Gd         TA      PConc        Gd
# 3         None           0.0         Gd         TA     CBlock        TA
# 4      BrkFace         247.0         TA         TA     CBlock        Gd
#
#   Bsmt Cond Bsmt Exposure BsmtFin Type 1  BsmtFin SF 1 BsmtFin Type 2  \
# 0        TA            No            Unf             0            Unf
# 1        TA            No            Unf             0            Unf
# 2        Gd            Av            GLQ           554            Unf
# 3        TA            No            Unf             0            Unf
# 4        TA            No            BLQ           609            Unf
#
#    BsmtFin SF 2  Bsmt Unf SF  Total Bsmt SF
# 0             0         1020           1020
# 1             0         1967           1967
# 2             0          100            654
# 3             0          968            968
# 4             0          785           1394

# %%
#checking for data types and null objects.
df_train.iloc[:, 20:40].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Year Built      879 non-null    int64
#  1   Year Remod/Add  879 non-null    int64
#  2   Roof Style      879 non-null    object
#  3   Roof Matl       879 non-null    object
#  4   Exterior 1st    879 non-null    object
#  5   Exterior 2nd    879 non-null    object
#  6   Mas Vnr Type    878 non-null    object
#  7   Mas Vnr Area    878 non-null    float64
#  8   Exter Qual      879 non-null    object
#  9   Exter Cond      879 non-null    object
#  10  Foundation      879 non-null    object
#  11  Bsmt Qual       854 non-null    object
#  12  Bsmt Cond       854 non-null    object
#  13  Bsmt Exposure   854 non-null    object
#  14  BsmtFin Type 1  854 non-null    object
#  15  BsmtFin SF 1    879 non-null    int64
#  16  BsmtFin Type 2  854 non-null    object
#  17  BsmtFin SF 2    879 non-null    int64
#  18  Bsmt Unf SF     879 non-null    int64
#  19  Total Bsmt SF   879 non-null    int64
# dtypes: float64(1), int64(6), object(13)
# memory usage: 137.5+ KB

# %%
df_train.iloc[:, 20:40].describe(include='all').T
# Out:
#                count unique      top freq     mean      std   min   25%   50%  \
# Year Built       879    NaN      NaN  NaN  1970.53  30.4035  1880  1954  1972
# Year Remod/Add   879    NaN      NaN  NaN  1984.44  20.4545  1950  1967  1992
# Roof Style       879      6    Gable  702      NaN      NaN   NaN   NaN   NaN
# Roof Matl        879      6  CompShg  862      NaN      NaN   NaN   NaN   NaN
# Exterior 1st     879     13  VinylSd  302      NaN      NaN   NaN   NaN   NaN
# Exterior 2nd     879     16  VinylSd  294      NaN      NaN   NaN   NaN   NaN
# Mas Vnr Type     878      5     None  534      NaN      NaN   NaN   NaN   NaN
# Mas Vnr Area     878    NaN      NaN  NaN  106.983  188.357     0     0     0
# Exter Qual       879      4       TA  552      NaN      NaN   NaN   NaN   NaN
# Exter Cond       879      5       TA  771      NaN      NaN   NaN   NaN   NaN
# Foundation       879      6    PConc  384      NaN      NaN   NaN   NaN   NaN
# Bsmt Qual        854      5       TA  396      NaN      NaN   NaN   NaN   NaN
# Bsmt Cond        854      3       TA  782      NaN      NaN   NaN   NaN   NaN
# Bsmt Exposure    854      4       No  567      NaN      NaN   NaN   NaN   NaN
# BsmtFin Type 1   854      6      Unf  248      NaN      NaN   NaN   NaN   NaN
# BsmtFin SF 1     879    NaN      NaN  NaN  443.397   442.48     0     0   374
# BsmtFin Type 2   854      6      Unf  750      NaN      NaN   NaN   NaN   NaN
# BsmtFin SF 2     879    NaN      NaN  NaN   53.835   178.54     0     0     0
# Bsmt Unf SF      879    NaN      NaN  NaN  539.519  426.083     0   216   453
# Total Bsmt SF    879    NaN      NaN  NaN  1036.75  419.258     0   790   975
#
#                   75%   max
# Year Built       2000  2010
# Year Remod/Add   2003  2010
# Roof Style        NaN   NaN
# Roof Matl         NaN   NaN
# Exterior 1st      NaN   NaN
# Exterior 2nd      NaN   NaN
# Mas Vnr Type      NaN   NaN
# Mas Vnr Area    173.5  1378
# Exter Qual        NaN   NaN
# Exter Cond        NaN   NaN
# Foundation        NaN   NaN
# Bsmt Qual         NaN   NaN
# Bsmt Cond         NaN   NaN
# Bsmt Exposure     NaN   NaN
# BsmtFin Type 1    NaN   NaN
# BsmtFin SF 1    735.5  2288
# BsmtFin Type 2    NaN   NaN
# BsmtFin SF 2        0  1526
# Bsmt Unf SF     781.5  2046
# Total Bsmt SF    1248  3138

# %% [markdown]
# ### 3.2. comments:
# - All dtypes of the 20 features are correct for what they suppose to represent
# - Missing datas:
#   - Mas Vnr Type, object
#   - Mas Vnr Area, float64
#   - Bsmt Qual, object
#   - Bsmt Cond,object
#   - Bsmt Exposure, object
#   - BsmtFin Type 1, object
#   - BsmtFin SF 1, float64
#   - BsmtFin Type 2, object
#   - BsmtFin SF 2, float64
#   - Bsmt Unf SF, float64
#   - Total Bsmt SF, float64
# - No Negative values noted

# %% [markdown]
# ## 3.3. Third 20 columns

# %%
# checking third 20 columns
df_train.iloc[:, 40:60].head()
# Out:
#   Heating Heating QC Central Air Electrical  1st Flr SF  2nd Flr SF  \
# 0    GasA         Gd           N      FuseP         908        1020
# 1    GasA         TA           Y      SBrkr        1967           0
# 2    GasA         Ex           Y      SBrkr         664         832
# 3    GasA         TA           Y      SBrkr         968           0
# 4    GasA         Gd           Y      SBrkr        1394           0
#
#    Low Qual Fin SF  Gr Liv Area  Bsmt Full Bath  Bsmt Half Bath  Full Bath  \
# 0                0         1928               0               0          2
# 1                0         1967               0               0          2
# 2                0         1496               1               0          2
# 3                0          968               0               0          1
# 4                0         1394               1               0          1
#
#    Half Bath  Bedroom AbvGr  Kitchen AbvGr Kitchen Qual  TotRms AbvGrd  \
# 0          0              4              2           Fa              9
# 1          0              6              2           TA             10
# 2          1              3              1           Gd              7
# 3          0              2              1           TA              5
# 4          1              3              1           TA              6
#
#   Functional  Fireplaces Fireplace Qu Garage Type
# 0        Typ           0          NaN      Detchd
# 1        Typ           0          NaN      Attchd
# 2        Typ           1           Gd      Attchd
# 3        Typ           0          NaN      Detchd
# 4        Typ           2           Gd      Attchd

# %%
# checking dtypes and null values
df_train.iloc[:, 40:60].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 20 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Heating          879 non-null    object
#  1   Heating QC       879 non-null    object
#  2   Central Air      879 non-null    object
#  3   Electrical       878 non-null    object
#  4   1st Flr SF       879 non-null    int64
#  5   2nd Flr SF       879 non-null    int64
#  6   Low Qual Fin SF  879 non-null    int64
#  7   Gr Liv Area      879 non-null    int64
#  8   Bsmt Full Bath   879 non-null    int64
#  9   Bsmt Half Bath   879 non-null    int64
#  10  Full Bath        879 non-null    int64
#  11  Half Bath        879 non-null    int64
#  12  Bedroom AbvGr    879 non-null    int64
#  13  Kitchen AbvGr    879 non-null    int64
#  14  Kitchen Qual     879 non-null    object
#  15  TotRms AbvGrd    879 non-null    int64
#  16  Functional       879 non-null    object
#  17  Fireplaces       879 non-null    int64
#  18  Fireplace Qu     457 non-null    object
#  19  Garage Type      835 non-null    object
# dtypes: int64(12), object(8)
# memory usage: 137.5+ KB

# %%
df_train.iloc[:, 40:60].describe(include='all').T
# Out:
#                 count unique     top freq       mean       std  min   25%  \
# Heating           879      4    GasA  867        NaN       NaN  NaN   NaN
# Heating QC        879      4      Ex  430        NaN       NaN  NaN   NaN
# Central Air       879      2       Y  824        NaN       NaN  NaN   NaN
# Electrical        878      4   SBrkr  814        NaN       NaN  NaN   NaN
# 1st Flr SF        879    NaN     NaN  NaN    1148.05   381.022  407   864
# 2nd Flr SF        879    NaN     NaN  NaN    349.752   434.595    0     0
# Low Qual Fin SF   879    NaN     NaN  NaN    2.72582   32.5541    0     0
# Gr Liv Area       879    NaN     NaN  NaN    1500.53   517.413  407  1114
# Bsmt Full Bath    879    NaN     NaN  NaN   0.440273  0.529983    0     0
# Bsmt Half Bath    879    NaN     NaN  NaN  0.0557452   0.22956    0     0
# Full Bath         879    NaN     NaN  NaN    1.54152  0.560908    0     1
# Half Bath         879    NaN     NaN  NaN   0.399317  0.506045    0     0
# Bedroom AbvGr     879    NaN     NaN  NaN    2.87941  0.830249    0     2
# Kitchen AbvGr     879    NaN     NaN  NaN    1.04778  0.223844    0     1
# Kitchen Qual      879      5      TA  447        NaN       NaN  NaN   NaN
# TotRms AbvGrd     879    NaN     NaN  NaN    6.45961   1.60307    3     5
# Functional        879      6     Typ  813        NaN       NaN  NaN   NaN
# Fireplaces        879    NaN     NaN  NaN   0.618885  0.669313    0     0
# Fireplace Qu      457      5      Gd  221        NaN       NaN  NaN   NaN
# Garage Type       835      6  Attchd  518        NaN       NaN  NaN   NaN
#
#                   50%   75%   max
# Heating           NaN   NaN   NaN
# Heating QC        NaN   NaN   NaN
# Central Air       NaN   NaN   NaN
# Electrical        NaN   NaN   NaN
# 1st Flr SF       1064  1358  3138
# 2nd Flr SF          0   720  2065
# Low Qual Fin SF     0     0   481
# Gr Liv Area      1436  1781  4676
# Bsmt Full Bath      0     1     2
# Bsmt Half Bath      0     0     1
# Full Bath           2     2     4
# Half Bath           0     1     2
# Bedroom AbvGr       3     3     6
# Kitchen AbvGr       1     1     3
# Kitchen Qual      NaN   NaN   NaN
# TotRms AbvGrd       6     7    12
# Functional        NaN   NaN   NaN
# Fireplaces          1     1     3
# Fireplace Qu      NaN   NaN   NaN
# Garage Type       NaN   NaN   NaN

# %% [markdown]
# ### 3.3. comments:
# - All dtypes of the 20 features are correct for what they suppose to represent
# - Missing datas:
#   - Bsmt Full Bath, float64
#   - Bsmt Half Bath, float 64
#   - Fireplace Qu, object
#   - Garage Type, object
# - No Negative values noted

# %% [markdown]
# ## 3.4. last 21 columns

# %%
# checking last 21 columns
df_train.iloc[:, 60:].head()
# Out:
#    Garage Yr Blt Garage Finish  Garage Cars  Garage Area Garage Qual  \
# 0         1910.0           Unf            1          440          Po
# 1         1977.0           Fin            2          580          TA
# 2         2006.0           RFn            2          426          TA
# 3         1935.0           Unf            2          480          Fa
# 4         1963.0           RFn            2          514          TA
#
#   Garage Cond Paved Drive  Wood Deck SF  Open Porch SF  Enclosed Porch  \
# 0          Po           Y             0             60             112
# 1          TA           Y           170              0               0
# 2          TA           Y           100             24               0
# 3          TA           N             0              0             184
# 4          TA           Y             0             76               0
#
#    3Ssn Porch  Screen Porch  Pool Area Pool QC Fence Misc Feature  Misc Val  \
# 0           0             0          0     NaN   NaN          NaN         0
# 1           0             0          0     NaN   NaN          NaN         0
# 2           0             0          0     NaN   NaN          NaN         0
# 3           0             0          0     NaN   NaN          NaN         0
# 4           0           185          0     NaN   NaN          NaN         0
#
#    Mo Sold  Yr Sold Sale Type
# 0        4     2006       WD
# 1        8     2006       WD
# 2        9     2006       New
# 3        7     2007       WD
# 4        7     2009       WD

# %%
df_train.iloc[:, 60:].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 20 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Garage Yr Blt   834 non-null    float64
#  1   Garage Finish   834 non-null    object
#  2   Garage Cars     879 non-null    int64
#  3   Garage Area     879 non-null    int64
#  4   Garage Qual     834 non-null    object
#  5   Garage Cond     834 non-null    object
#  6   Paved Drive     879 non-null    object
#  7   Wood Deck SF    879 non-null    int64
#  8   Open Porch SF   879 non-null    int64
#  9   Enclosed Porch  879 non-null    int64
#  10  3Ssn Porch      879 non-null    int64
#  11  Screen Porch    879 non-null    int64
#  12  Pool Area       879 non-null    int64
#  13  Pool QC         4 non-null      object
#  14  Fence           172 non-null    object
#  15  Misc Feature    41 non-null     object
#  16  Misc Val        879 non-null    int64
#  17  Mo Sold         879 non-null    int64
#  18  Yr Sold         879 non-null    int64
#  19  Sale Type       879 non-null    object
# dtypes: float64(1), int64(11), object(8)
# memory usage: 137.5+ KB

# %%
df_train.iloc[:, 60:].describe(include='all').T
# Out:
#                count unique    top freq     mean       std   min   25%   50%  \
# Garage Yr Blt    834    NaN    NaN  NaN   1976.8   25.6957  1900  1960  1978
# Garage Finish    834      3    Unf  382      NaN       NaN   NaN   NaN   NaN
# Garage Cars      879    NaN    NaN  NaN  1.74403  0.751162     0     1     2
# Garage Area      879    NaN    NaN  NaN  470.833    213.07     0   323   473
# Garage Qual      834      4     TA  783      NaN       NaN   NaN   NaN   NaN
# Garage Cond      834      5     TA  797      NaN       NaN   NaN   NaN   NaN
# Paved Drive      879      3      Y  791      NaN       NaN   NaN   NaN   NaN
# Wood Deck SF     879    NaN    NaN  NaN  93.5609   121.174     0     0     0
# Open Porch SF    879    NaN    NaN  NaN   47.479   69.2092     0     0    27
# Enclosed Porch   879    NaN    NaN  NaN  24.0375   73.2122     0     0     0
# 3Ssn Porch       879    NaN    NaN  NaN  2.59499   24.9484     0     0     0
# Screen Porch     879    NaN    NaN  NaN  14.8134    52.976     0     0     0
# Pool Area        879    NaN    NaN  NaN  1.88282   29.8997     0     0     0
# Pool QC            4      2     Ex    3      NaN       NaN   NaN   NaN   NaN
# Fence            172      4  MnPrv  103      NaN       NaN   NaN   NaN   NaN
# Misc Feature      41      3   Shed   39      NaN       NaN   NaN   NaN   NaN
# Misc Val         879    NaN    NaN  NaN  48.4437   549.858     0     0     0
# Mo Sold          879    NaN    NaN  NaN  6.20705    2.6441     1     5     6
# Yr Sold          879    NaN    NaN  NaN  2007.82    1.3274  2006  2007  2008
# Sale Type        879     10    WD   755      NaN       NaN   NaN   NaN   NaN
#
#                  75%    max
# Garage Yr Blt   2001   2010
# Garage Finish    NaN    NaN
# Garage Cars        2      4
# Garage Area      576   1488
# Garage Qual      NaN    NaN
# Garage Cond      NaN    NaN
# Paved Drive      NaN    NaN
# Wood Deck SF     171    690
# Open Porch SF     70    742
# Enclosed Porch     0   1012
# 3Ssn Porch         0    360
# Screen Porch       0    576
# Pool Area          0    555
# Pool QC          NaN    NaN
# Fence            NaN    NaN
# Misc Feature     NaN    NaN
# Misc Val           0  15500
# Mo Sold            8     12
# Yr Sold         2009   2010
# Sale Type        NaN    NaN

# %% [markdown]
# ### 3.4. comments:
# - All dtypes of the 20 features are correct for what they suppose to represent
# - Missing datas:
#   - Garage Yr Blt, float64
#   -  Garage Finish, object
#   - Garage Cars, float64
#   - Garage Area, float 64
#   - Garage Qual, object
#   - Garage Cond, object
#   - Pool QC, object
#   - Fence, object
#   - Misc Feature, object
# - No Negative values noted

# %% [markdown]
# # 4. Data Cleaning

# %% [markdown]
# ### 4.1. Counting the missing values

# %%
#checking the count and list of nan values
nan_values = df_train.isna().sum().sort_values(ascending = False)
nan_values_list = nan_values[nan_values >= 1]
nan_values_list
# Out:
# Pool QC           875
# Misc Feature      838
# Alley             821
# Fence             707
# Fireplace Qu      422
# Lot Frontage      160
# Garage Cond        45
# Garage Qual        45
# Garage Yr Blt      45
# Garage Finish      45
# Garage Type        44
# Bsmt Exposure      25
# BsmtFin Type 1     25
# Bsmt Qual          25
# BsmtFin Type 2     25
# Bsmt Cond          25
# Mas Vnr Area        1
# Mas Vnr Type        1
# Electrical          1
# dtype: int64

# %% [markdown]
# ### 4.1. comments
# Missing values above will either be removed or filled in after manual inspection with data dictionary

# %% [markdown]
# # 4.2. Filling Missing values

# %% [markdown]
# ## 4.2.1 Filling Missing values in Pool QC
# - Base on data dictionary, empty values suppose to be houses without pools
# - Thus the information will need to be filled in

# %%
#importing datasets without NA filter
df_train_nona = pd.read_csv('../datasets/train.csv', na_filter = False)
df_train_nona.head()
# Out:
#     Id        PID  MS SubClass MS Zoning Lot Frontage  Lot Area Street Alley  \
# 0  109  533352170           60        RL                  13517   Pave    NA
# 1  544  531379050           60        RL           43     11492   Pave    NA
# 2  153  535304180           20        RL           68      7922   Pave    NA
# 3  318  916386060           60        RL           73      9802   Pave    NA
# 4  255  906425045           50        RL           82     14235   Pave    NA
#
#   Lot Shape Land Contour  ... Screen Porch Pool Area Pool QC Fence  \
# 0       IR1          Lvl  ...            0         0      NA    NA
# 1       IR1          Lvl  ...            0         0      NA    NA
# 2       Reg          Lvl  ...            0         0      NA    NA
# 3       Reg          Lvl  ...            0         0      NA    NA
# 4       IR1          Lvl  ...            0         0      NA    NA
#
#   Misc Feature Misc Val Mo Sold Yr Sold  Sale Type  SalePrice
# 0           NA        0       3    2010        WD      130500
# 1           NA        0       4    2009        WD      220000
# 2           NA        0       1    2010        WD      109000
# 3           NA        0       4    2010        WD      174000
# 4           NA        0       3    2010        WD      138500
#
# [5 rows x 81 columns]

# %%
#checking for unique values
df_train['Pool QC'].unique()
# Out:
# array([nan, 'Ex', 'TA'], dtype=object)

# %%
#checking for unique values
df_train_nona['Pool QC'].unique()
# Out:
# array(['NA', 'Fa', 'Gd', 'Ex', 'TA'], dtype=object)

# %%
#replacing nan value with NA for Pool QC
df_train['Pool QC'].fillna('NA', inplace = True)
#checking unique values of Pool QC
df_train['Pool QC'].unique()
# Out:
# array(['NA', 'Ex', 'TA'], dtype=object)

# %% [markdown]
# ### 4.2.1 comments:
# All missing values in 'Pool QC' has been filled

# %% [markdown]
# ## 4.2.2 Filling missing values in Misc Feature
# - base on data dictionary, missing values should be house without misc feature
# - thus information will need to be filled in

# %%
#checking for unique values
df_train['Misc Feature'].unique()
# Out:
# array([nan, 'Shed', 'Othr', 'Gar2'], dtype=object)

# %%
#checking for unique values
df_train_nona['Misc Feature'].unique()
# Out:
# array(['NA', 'Shed', 'TenC', 'Gar2', 'Othr', 'Elev'], dtype=object)

# %%
#replacing nan value with NA for Misc Feature
df_train['Misc Feature'].fillna('NA', inplace = True)
#checking unique values of Pool QC
df_train['Misc Feature'].unique()
# Out:
# array(['NA', 'Shed', 'Othr', 'Gar2'], dtype=object)

# %% [markdown]
# ### 4.2.2 comments:
# All missing values in 'Misc Feature' has been filled

# %% [markdown]
# ## 4.2.3 Filling missing values in Alley category
# - base on data dictionary, missing values should be house without alley access
# - thus information will need to be filled in

# %%
#checking for unique values
df_train['Alley'].unique()
# Out:
# array(['Grvl', nan, 'Pave'], dtype=object)

# %%
#checking for unique values
df_train_nona['Alley'].unique()
# Out:
# array(['NA', 'Pave', 'Grvl'], dtype=object)

# %%
#replacing nan value with NA for Alley
df_train['Alley'].fillna('NA', inplace = True)
#checking unique values of Pool QC
df_train['Alley'].unique()
# Out:
# array(['Grvl', 'NA', 'Pave'], dtype=object)

# %% [markdown]
# ### 4.2.3 comments:
# All missing values in 'Alley' has been filled

# %% [markdown]
# ## 4.2.4 Filling missing values in Fence category
# - base on data dictionary, missing values should be house without fence
# - thus information will need to be filled in

# %%
#checking for unique values
df_train['Fence'].unique()
# Out:
# array([nan, 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
#checking for unique values
df_train_nona['Fence'].unique()
# Out:
# array(['NA', 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %%
#replacing nan value with NA for Alley
df_train['Fence'].fillna('NA', inplace = True)
#checking unique values of Pool QC
df_train['Fence'].unique()
# Out:
# array(['NA', 'MnPrv', 'GdPrv', 'GdWo', 'MnWw'], dtype=object)

# %% [markdown]
# ### 4.2.4 comments:
# All missing values in 'Fence' has been filled

# %% [markdown]
# ## 4.2.5 Filling missing values in Fireplace QU
# - base on data dictionary, missing values should be house without fireplaces
# - thus information will need to be filled in

# %%
#checking for unique values
df_train['Fireplace Qu'].unique()
# Out:
# array([nan, 'Gd', 'Fa', 'TA', 'Po', 'Ex'], dtype=object)

# %%
#checking for unique values
df_train_nona['Fireplace Qu'].unique()
# Out:
# array(['NA', 'TA', 'Gd', 'Po', 'Ex', 'Fa'], dtype=object)

# %%
#replacing nan value with NA for Alley
df_train['Fireplace Qu'].fillna('NA', inplace = True)
#checking unique values of Pool QC
df_train['Fireplace Qu'].unique()
# Out:
# array(['NA', 'Gd', 'Fa', 'TA', 'Po', 'Ex'], dtype=object)

# %% [markdown]
# ### 4.2.5 comments:
# All missing values in 'Fireplace QU' has been filled

# %% [markdown]
# ## 4.2.6 Filling missing values in Lot Frontage
# - base on data dictionary, missing values should be Linear feet of street connected to property
# - adding in 0 for missing values to keep the datatype as a float

# %%
#checking for null values
df_train['Lot Frontage'].isnull().sum()
# Out:
# 160

# %%
#replacing nan value with 0 for Lot Frontage
df_train['Lot Frontage'].fillna(0, inplace = True)

# %%
#checking for null values
df_train['Lot Frontage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# ### 4.2.6 comments:
# All missing values in 'Lot Frontage' has been filled

# %% [markdown]
# # 4.2.7 Handling Garage related columns

# %%
#Filtering Garage related columns
df_garage = df_train.filter(regex='Garage')
df_garage.isnull().sum()
# Out:
# Garage Type      44
# Garage Yr Blt    45
# Garage Finish    45
# Garage Cars       0
# Garage Area       0
# Garage Qual      45
# Garage Cond      45
# dtype: int64

# %%
#checking dtypes
df_garage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Garage Type    835 non-null    object
#  1   Garage Yr Blt  834 non-null    float64
#  2   Garage Finish  834 non-null    object
#  3   Garage Cars    879 non-null    int64
#  4   Garage Area    879 non-null    int64
#  5   Garage Qual    834 non-null    object
#  6   Garage Cond    834 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 48.2+ KB

# %% [markdown]
# - 'Garage Type', 'Garage Finish', 'Garage Qual' and 'Garage Cond'should have NA values in them.
# - 'Garage Yr Blt' refers to year Garage is built, so a number need to be insert for dtype to remain float
# - Garage cars and Garage area denotes the number of car and area size of garade, therefore a number need to be filled in for nan values

# %%
#filling dtypes object nan values
df_train['Garage Type'].fillna('NA', inplace = True)
df_train['Garage Finish'].fillna('NA', inplace = True)
df_train['Garage Qual'].fillna('NA', inplace = True)
df_train['Garage Cond'].fillna('NA', inplace = True)

#filling dtypes float64 nan values with number 0
df_train['Garage Yr Blt'].fillna(0 , inplace = True)
df_train['Garage Cars'].fillna(0 , inplace = True)
df_train['Garage Area'].fillna(0 , inplace = True)

# %%
df_garage = df_train.filter(regex='Garage')
df_garage.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 7 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Garage Type    879 non-null    object
#  1   Garage Yr Blt  879 non-null    float64
#  2   Garage Finish  879 non-null    object
#  3   Garage Cars    879 non-null    int64
#  4   Garage Area    879 non-null    int64
#  5   Garage Qual    879 non-null    object
#  6   Garage Cond    879 non-null    object
# dtypes: float64(1), int64(2), object(4)
# memory usage: 48.2+ KB

# %% [markdown]
# ### 4.2.7. Comments
#
# All missing values in Garage category has been filled

# %% [markdown]
# # 4.2.8 Handling Basement related columns

# %%
df_bsmt = df_train.filter(regex='Bsmt')
df_bsmt.isnull().sum()
# Out:
# Bsmt Qual         25
# Bsmt Cond         25
# Bsmt Exposure     25
# BsmtFin Type 1    25
# BsmtFin SF 1       0
# BsmtFin Type 2    25
# BsmtFin SF 2       0
# Bsmt Unf SF        0
# Total Bsmt SF      0
# Bsmt Full Bath     0
# Bsmt Half Bath     0
# dtype: int64

# %%
df_bsmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bsmt Qual       854 non-null    object
#  1   Bsmt Cond       854 non-null    object
#  2   Bsmt Exposure   854 non-null    object
#  3   BsmtFin Type 1  854 non-null    object
#  4   BsmtFin SF 1    879 non-null    int64
#  5   BsmtFin Type 2  854 non-null    object
#  6   BsmtFin SF 2    879 non-null    int64
#  7   Bsmt Unf SF     879 non-null    int64
#  8   Total Bsmt SF   879 non-null    int64
#  9   Bsmt Full Bath  879 non-null    int64
#  10  Bsmt Half Bath  879 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 75.7+ KB

# %% [markdown]
# - BsmtFin SF 1, BsmtFin SF 2, Bsmt Unf SF, Total Bsmt SF, Bsmt Full Bath,Bsmt Half Bath has values as float, which are all regarding measurements, missing values to fill in as 0
# - Bsmt Qual, Bsmt Cond, Bsmt Exposure, BsmtFin Type 1, BsmtFin Type 2 are all values with categories, like quality and conditions of basement. missing values to be filled with NA.

# %%
#filling dtypes object nan values
df_train['Bsmt Qual'].fillna('NA', inplace = True)
df_train['Bsmt Cond'].fillna('NA', inplace = True)
df_train['Bsmt Exposure'].fillna('NA', inplace = True)
df_train['BsmtFin Type 1'].fillna('NA', inplace = True)
df_train['BsmtFin Type 2'].fillna('NA', inplace = True)

#filling dtypes float64 nan values with number 0
df_train['BsmtFin SF 1'].fillna(0 , inplace = True)
df_train['BsmtFin SF 2'].fillna(0 , inplace = True)
df_train['Bsmt Unf SF'].fillna(0 , inplace = True)
df_train['Total Bsmt SF'].fillna(0 , inplace = True)
df_train['Bsmt Full Bath'].fillna(0 , inplace = True)
df_train['Bsmt Half Bath'].fillna(0 , inplace = True)

# %%
df_bsmt = df_train.filter(regex='Bsmt')
df_bsmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 11 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Bsmt Qual       879 non-null    object
#  1   Bsmt Cond       879 non-null    object
#  2   Bsmt Exposure   879 non-null    object
#  3   BsmtFin Type 1  879 non-null    object
#  4   BsmtFin SF 1    879 non-null    int64
#  5   BsmtFin Type 2  879 non-null    object
#  6   BsmtFin SF 2    879 non-null    int64
#  7   Bsmt Unf SF     879 non-null    int64
#  8   Total Bsmt SF   879 non-null    int64
#  9   Bsmt Full Bath  879 non-null    int64
#  10  Bsmt Half Bath  879 non-null    int64
# dtypes: int64(6), object(5)
# memory usage: 75.7+ KB

# %% [markdown]
# ### 4.2.8. Comments
#
# All missing values in Basement category has been filled

# %% [markdown]
# # 4.2.9 Handling Mansory related columns

# %%
df_bsmt = df_train.filter(regex='Mas')
df_bsmt.isnull().sum()
# Out:
# Mas Vnr Type    1
# Mas Vnr Area    1
# dtype: int64

# %%
df_bsmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Mas Vnr Type  878 non-null    object
#  1   Mas Vnr Area  878 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# - Mas Vnr Type is a categorical label, therefore filling missing data with NA
# - Mas Vnr Area is the measurement of the Mansory, therefore filling the missing value with 0 to keep the datatype a float

# %%
#filling dtypes object nan values
df_train['Mas Vnr Type'].fillna('NA' , inplace = True)

#filling dtypes float64 nan values with number 0
df_train['Mas Vnr Area'].fillna(0 , inplace = True)

# %%
df_bsmt = df_train.filter(regex='Mas')
df_bsmt.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 2 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Mas Vnr Type  879 non-null    object
#  1   Mas Vnr Area  879 non-null    float64
# dtypes: float64(1), object(1)
# memory usage: 13.9+ KB

# %% [markdown]
# ### 4.2.9. Comments
#
# All missing values in Mansory category has been filled

# %%
#final check for any null values in dataset
df_train.isnull().sum().sum()
# Out:
# 1

# %% [markdown]
# All Missing values have been filled!

# %%
df_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 879 entries, 0 to 878
# Data columns (total 80 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Id               879 non-null    int64
#  1   PID              879 non-null    int64
#  2   MS SubClass      879 non-null    int64
#  3   MS Zoning        879 non-null    object
#  4   Lot Frontage     879 non-null    float64
#  5   Lot Area         879 non-null    int64
#  6   Street           879 non-null    object
#  7   Alley            879 non-null    object
#  8   Lot Shape        879 non-null    object
#  9   Land Contour     879 non-null    object
#  10  Utilities        879 non-null    object
#  11  Lot Config       879 non-null    object
#  12  Land Slope       879 non-null    object
#  13  Neighborhood     879 non-null    object
#  14  Condition 1      879 non-null    object
#  15  Condition 2      879 non-null    object
#  16  Bldg Type        879 non-null    object
#  17  House Style      879 non-null    object
#  18  Overall Qual     879 non-null    int64
#  19  Overall Cond     879 non-null    int64
#  20  Year Built       879 non-null    int64
#  21  Year Remod/Add   879 non-null    int64
#  22  Roof Style       879 non-null    object
#  23  Roof Matl        879 non-null    object
#  24  Exterior 1st     879 non-null    object
#  25  Exterior 2nd     879 non-null    object
#  26  Mas Vnr Type     879 non-null    object
#  27  Mas Vnr Area     879 non-null    float64
#  28  Exter Qual       879 non-null    object
#  29  Exter Cond       879 non-null    object
#  30  Foundation       879 non-null    object
#  31  Bsmt Qual        879 non-null    object
#  32  Bsmt Cond        879 non-null    object
#  33  Bsmt Exposure    879 non-null    object
#  34  BsmtFin Type 1   879 non-null    object
#  35  BsmtFin SF 1     879 non-null    int64
#  36  BsmtFin Type 2   879 non-null    object
#  37  BsmtFin SF 2     879 non-null    int64
#  38  Bsmt Unf SF      879 non-null    int64
#  39  Total Bsmt SF    879 non-null    int64
#  40  Heating          879 non-null    object
#  41  Heating QC       879 non-null    object
#  42  Central Air      879 non-null    object
#  43  Electrical       878 non-null    object
#  44  1st Flr SF       879 non-null    int64
#  45  2nd Flr SF       879 non-null    int64
#  46  Low Qual Fin SF  879 non-null    int64
#  47  Gr Liv Area      879 non-null    int64
#  48  Bsmt Full Bath   879 non-null    int64
#  49  Bsmt Half Bath   879 non-null    int64
#  50  Full Bath        879 non-null    int64
#  51  Half Bath        879 non-null    int64
#  52  Bedroom AbvGr    879 non-null    int64
#  53  Kitchen AbvGr    879 non-null    int64
#  54  Kitchen Qual     879 non-null    object
#  55  TotRms AbvGrd    879 non-null    int64
#  56  Functional       879 non-null    object
#  57  Fireplaces       879 non-null    int64
#  58  Fireplace Qu     879 non-null    object
#  59  Garage Type      879 non-null    object
#  60  Garage Yr Blt    879 non-null    float64
#  61  Garage Finish    879 non-null    object
#  62  Garage Cars      879 non-null    int64
#  63  Garage Area      879 non-null    int64
#  64  Garage Qual      879 non-null    object
#  65  Garage Cond      879 non-null    object
#  66  Paved Drive      879 non-null    object
#  67  Wood Deck SF     879 non-null    int64
#  68  Open Porch SF    879 non-null    int64
#  69  Enclosed Porch   879 non-null    int64
#  70  3Ssn Porch       879 non-null    int64
#  71  Screen Porch     879 non-null    int64
#  72  Pool Area        879 non-null    int64
#  73  Pool QC          879 non-null    object
#  74  Fence            879 non-null    object
#  75  Misc Feature     879 non-null    object
#  76  Misc Val         879 non-null    int64
#  77  Mo Sold          879 non-null    int64
#  78  Yr Sold          879 non-null    int64
#  79  Sale Type        879 non-null    object
# dtypes: float64(3), int64(35), object(42)
# memory usage: 549.5+ KB

# %%
#Exporting data for EDA in next notebook
df_train.to_csv("../datasets/test_clean.csv", index=False)

# %% [markdown]
# # To be continued
